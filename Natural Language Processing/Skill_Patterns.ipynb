# %%
import json

# %%
# Engage / manage networks
networks1 = {"label": "NETWORKS1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'stakeholder'}]}
networks2 = {"label": "NETWORKS2", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'ADJ', 'OP': '?'}, {'LEMMA': 'network'}]}

# Policy
policy1 = {"label": "POLICY1", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'policy mix'}]}  
policy2 = {"label": "POLICY2", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'policy'}, {'LEMMA': 'mix'}]}
policy3 = {"label": "POLICY3", "pattern": [{'LEMMA': 'policy'}, {'LEMMA': 'coordination'}]}
policy4 = {"label": "POLICY4", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'NOUN', 'OP': '?'}, {'LEMMA': 'goal'}]}
policy5 = {"label": "POLICY5", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'goal'}]}
policy6 = {"label": "POLICY6", "pattern": [{"LEMMA": "change"}, {"LEMMA": "policy"}, {"LEMMA": "condition"}]}

# Intervention design 
intervention1 =  {"label": "INT1", "pattern": [{'LEMMA': 'portfolio'}]}  # e.g., portfolio approach
intervention2 =  {"label": "INT2", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'portfolio'}]}
intervention3 =  {"label": "INT3", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'directionality'}]}
intervention4 =  {"label": "INT4", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'directionality'}]}
intervention5 =  {"label": "INT5", "pattern": [{'LEMMA': 'secure'}, {'LEMMA': 'directionality'}]}  
intervention6 =  {"label": "INT6", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'direction'}]}
intervention7 =  {"label": "INT7", "pattern": [{'LEMMA': 'direct'}, {'POS': 'NOUN', 'OP': '+'}]}
intervention8 =  {"label": "INT8", "pattern": [{'LEMMA': 'whole'}, {'LEMMA': 'system'}, {'LEMMA': 'knowledge'}]}
intervention9 =  {"label": "INT9", "pattern": [{'LEMMA': 'mobilise'}, {'LEMMA': 'policy'}, {'POS': 'NOUN', 'OP': '?'}]}
intervention10 =  {"label": "INT10", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'change'}]}
intervention11 =  {"label": "INT11", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'change'}]}
intervention12 = {"label": "INT12", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'ecosystem'}]}
intervention13 = {"label": "INT13", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'innovation'}, {'LEMMA': 'process'}]}
intervention14 = {"label": "INT14", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'ADJ', 'OP': '?'}, {'LEMMA': 'instrument'}]}
intervention15 = {"label": "INT15", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'lever'}]}
intervention16 = {"label": "INT16", "pattern": [{'LEMMA': 'co'}, {'LEMMA': '-'}, {'LEMMA': 'creation'}]}

# Buy-in (e.g., secure / achieve commitments)
buy_in1 =  {"label": "BUY_IN1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'commitment'}]}
buy_in2 =  {"label": "BUY_IN2", "pattern": [{'LEMMA': 'engage'}, {'LEMMA': 'citizen'}]}
buy_in3 =  {"label": "BUY_IN3", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'legitimacy'}]}
buy_in4 =  {"label": "BUY_IN4", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'legitimacy'}]}
buy_in5 =  {"label": "BUY_IN5", "pattern": [{'LEMMA': 'participatory'}]}
buy_in6 =  {"label": "BUY_IN6", "pattern": [{'POS': 'ADJ', 'OP': '?'}, {'POS': 'NOUN', 'OP': '?'}, {'POS': 'VERB', 'OP': '?'}, {'LEMMA': 'buy'}, {'LEMMA': '-'}, {'LEMMA': 'in'}]}
buy_in7 =  {"label": "BUY_IN7", "pattern": [{'LEMMA': 'citizen'}, {'LEMMA': 'engagement'}]}
buy_in8 =  {"label": "BUY_IN8", "pattern": [{'LEMMA': 'engagment'}, {'LEMMA': 'process'}]}
buy_in9 = {"label": "BUY_IN9", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'trust'}]} 

# Structures
struct1 = {"label": "STRUCT1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'silo'}]}  

# System Change
sys_change1 = {"label": "SYS1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'intentionality'}]}  # e.g., achieve intentionality
sys_change2 = {"label": "SYS2", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'intentionality'}]}  
sys_change3 = {"label": "SYS3", "pattern": [{'LEMMA': 'mobilise'}, {'POS': 'NOUN', 'OP': '?'}]}  # e.g., mobilise stakeholders
sys_change4 = {"label": "SYS4", "pattern":[{'POS': 'VERB', 'OP': '+'},{'LEMMA': 'systematically'}]}
sys_change5 = {"label": "SYS5", "pattern": [{'LEMMA': 'system'}, {'LEMMA': 'transformation'}]}
sys_change6 = {"label": "SYS6", "pattern": [{"LEMMA": "create"}, {"LEMMA": "new"}, {"LEMMA": "market"}]}
sys_change7 = {"label": "SYS7", "pattern": [{'LEMMA': 'strategic'}, {'POS': 'NOUN', 'OP': '+'}]}

#Learning
learning1 = {"label": "LEARNING1", "pattern": [{'LEMMA': 'reflexivity'}]}
learning2 = {"label": "LEARNING2", "pattern": [{'LEMMA': 'iterative'}, {'LEMMA': 'learning'}]}
learning3 = {"label": "LEARNING3", "pattern": [{'LEMMA': 'reflexive'}, {'LEMMA': 'learn'}]}
learning4 = {"label": "LEARNING4", "pattern": [{'LEMMA': 'ongoing'}, {'LEMMA': 'learning'}]}
learning5 = {"label": "LEARNING5", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'ADP', 'OP': '?'}, {'LEMMA': 'loop'}, {'LEMMA': 'of'}, {'LEMMA': 'learn'}]}
learning6 = {"label": "LEARNING6", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'learn'},{'ORTH': 'loop'}]}
learning7 = {"label": "LEARNING7", "pattern": [{'LEMMA': 'flow'}, {'LEMMA': 'of'}, {'LEMMA': 'learn'}]}
learning8 = {"label": "LEARNING8", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'double'}, {'LEMMA': 'loop'},{'LEMMA': 'learning'}]}
learning9 = {"label": "LEARNING9", "pattern": [{'LEMMA': 'learn'}, {'POS': 'ADP', 'OP': '+'}, {'LEMMA': 'engagement', 'OP': '+'}]}
learning10 = {"label": "LEARNING10", "pattern": [{'LEMMA': 'continual'}, {'LEMMA': 'learning'}]}
learning11 = {"label": "LEARNING11", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'feedback'},{'ORTH': 'loop'}]}

# Tools, approaches, methods
tools1 =  {"label": "TOOLS1", "pattern": [{'LEMMA': 'system canvas'}]}
tools2 =  {"label": "TOOLS2", "pattern": [{'LEMMA': 'foresight'}]}
tools3 =  {"label": "TOOLS3", "pattern": [{'LEMMA': 'visualisation'}]}
tools4 =  {"label": "TOOLS4", "pattern":[{'LEMMA': 'design method'}]}
tools5 =  {"label": "TOOLS5", "pattern": [{'POS': 'VERB', 'OP': '+'},{'LEMMA': 'prototype'}]}
tools6 =  {"label": "TOOLS6", "pattern": [{'POS': 'ADJ', 'OP': '?'},{'LEMMA': 'prototype'}]}
tools7 =  {"label": "TOOLS7", "pattern": [{"LEMMA": "storytelling"}]}
tools8 =  {"label": "TOOLS8", "pattern": [{"LEMMA": "foresight"}]}
tools9 =  {"label": "TOOLS9", "pattern": [{"LEMMA": "design"}, {"LEMMA": "artifact"}]}  
tools10 = {"label": "TOOLS10", "pattern": [{"LEMMA": "system"}, {"LEMMA": "mapping"}]}
tools11 = {"label": "TOOLS11", "pattern": [{"LEMMA": "problem"}, {"LEMMA": "exploration"}]}
tools12 = {"label": "TOOLS12", "pattern": [{"LEMMA": "scenario"}, {"LEMMA": "design"}]}
tools13 = {"label": "TOOLS13", "pattern": [{'LEMMA': 'co'}, {'LEMMA': '-'}, {'LEMMA': 'creation'}]}
tools14 = {"label": "TOOLs14", "pattern": [{"LEMMA": "visualisation"}, {"LEMMA": "tool"}]}
tools15 = {"label": "TOOLS15", "pattern": [{'LEMMA': 'co'}, {'LEMMA': '-'}, {'LEMMA': 'production'}]}
tools16 = {"label": "TOOLs16", "pattern": [{"LEMMA": "agile"}, {"LEMMA": "development"}]}
tools17 = {"label": "TOOLS17", "pattern": [{'LEMMA': 'experiment'}]}
tools18 = {"label": "TOOLS18", "pattern": [{'LEMMA': 'experimental'}]}
tools19 = {"label": "TOOLS19", "pattern": [{'LEMMA': 'experimentation'}]}
tools20 = {"label": "TOOLS20", "pattern": [{'LEMMA': 'co'}, {'LEMMA': '-'}, {'LEMMA': 'design'}]}
tools21 = {"label": "TOOLS21", "pattern": [{'LEMMA': 'ethonography'}]}
tools22 = {"label": "TOOLS22", "pattern": [{'LEMMA': 'anthropology'}]}
tools23 = {"label": "TOOLS23", "pattern": [{'LEMMA': 'randomise'}, {'LEMMA': 'control'}, {'LEMMA': 'trial'}]}
tools24 = {"label": "TOOLS24", "pattern": [{"LEMMA": "action"}, {"LEMMA": "research"}]}
tools25 = {"label": "TOOLS25", "pattern": [{"LEMMA": "creative"}, {"LEMMA": "facilitation"}]}
tools26 = {"label": "TOOLS26", "pattern": [{"LEMMA": "horizon"}, {"LEMMA": "scan"}]}

#Inter-disciplinarity
id1 = {"label": "ID1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'multidisciplinary'}, {'POS': 'NOUN', 'OP': '?'}]}
id2 = {"label": "ID2", "pattern": [{'LEMMA': 'interdisciplinary'}]}
id3 = {"label": "ID3", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'transdisciplinary'}, {'POS': 'NOUN', 'OP': '?'}]}
id4 = {"label": "ID4", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'ADP', 'OP': '+'}, {'LEMMA': 'discipline'}]}
id5 = {"label": "ID5", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'ADP', 'OP': '+'}, {'LEMMA': 'sector'}]}
id6 = {"label": "ID6", "pattern": [{'LEMMA': 'translate'}, {'POS': 'NOUN', 'OP': '?'}, {'POS': 'ADP'}, {'LEMMA': 'discipline'}]}
id7 = {"label": "ID7", "pattern": [{'LEMMA': 'knowledge'}, {'LEMMA': 'integration'}]}
id8 = {"label": "ID8", "pattern": [{'LEMMA': 'integration'}, {'LEMMA': 'of'}, {'POS': 'NOUN', 'OP': '+'}, {'POS': 'CCONJ', 'OP': '?'}, {'POS': 'NOUN', 'OP': '?'}]}
id9 = {"label": "ID9", "pattern": [{'LEMMA': 'integrate'}, {'POS': 'NOUN', 'OP': '+'}, {'POS': 'CCONJ', 'OP': '?'}, {'POS': 'NOUN', 'OP': '?'}]}
id10 = {"label": "ID10", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'disciplinary'}, {'LEMMA': 'diversity'}]}
id11 = {"label": "ID11", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'a', 'OP': '?'}, {'LEMMA': 'the', 'OP': '?'}, {'LEMMA': 'share', 'OP': '?'}, {'LEMMA': 'common', 'OP': '?'}, {'LEMMA': 'mission'}]}
id12 = {"label": "ID12", "pattern": [{'LEMMA': 'take', 'OP': '+'}, {'POS': 'ADJ', 'OP': '?'}, {'LEMMA': 'risk'}]}
id13 = {"label": "ID13", "pattern": [{'LEMMA': 'risk', 'OP': '+'}, {'LEMMA': 'take'}]}
id14 = {"label": "ID14", "pattern": [{'LEMMA': 'cross'}, {'LEMMA': '-'}, {'LEMMA': 'disciplinary'}, {'POS': 'NOUN', 'OP': '+'}]}

#Delivery
delivery1 = {"label": "DEL1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'horizontal'}, {'LEMMA': 'coordination'}]}
delivery2 = {"label": "DEL2", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'vertical'}, {'LEMMA': 'coordination'}]}
delivery3 = {"label": "DEL3", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'horizontal'}, {'LEMMA': 'coordination'}]}
delivery4 = {"label": "DEL4", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'vertical'}, {'LEMMA': 'coordination'}]}
delivery5 = {"label": "DEL5", "pattern": [{'POS': 'NOUN'}, {'POS': 'ADP'}, {'LEMMA': 'policy'},{'LEMMA': 'domain'}]}
delivery6 = {"label": "DEL6", "pattern": [{'POS': 'VERB'}, {'POS': 'ADP'}, {'LEMMA': 'policy'},{'LEMMA': 'domain'}]}
delivery7 = {"label": "DEL7", "pattern": [{'LEMMA': 'dynamic'}, {'LEMMA': 'portfolio'},{'LEMMA': 'management'}]}
delivery8 = {"label": "DEL8", "pattern": [{'LEMMA': 'strategic'}, {'LEMMA': 'navigation'}]}
delivery9 = {"label": "DEL9", "pattern": [{'POS': 'VERB', 'OP': '?'}, {'POS': 'NOUN', 'OP': '?'}, {'LEMMA': 'coalition'}]}

#Mindset
mindset1 = {"label": "mindset1", "pattern": [{'LEMMA': 'agility'}]}
mindset2 = {"label": "mindset2", "pattern": [{'LEMMA': 'flexibility'}]} 
mindset3 = {"label": "mindset3", "pattern": [{'LEMMA': 'goal'}, {'LEMMA': 'orientate'}]}
mindset4 = {"label": "mindset4", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'POS': 'NOUN', 'OP': '?'},{'POS': 'ADP', 'OP': '?'}, {'LEMMA': 'uncertainty'}]}
mindset5 = {"label": "mindset5", "pattern": [{'LEMMA': 'curiousity'}]}
mindset6 = {"label": "mindset6", "pattern": [{'LEMMA': 'curious'}]}
mindset7 = {"label": "mindset7", "pattern": [{'LEMMA': 'empathy'}]}
mindset8 = {"label": "mindset8", "pattern": [{'LEMMA': 'patience'}]}
mindset9 = {"label": "mindset9", "pattern": [{'LEMMA': 'adaptability'}]}
mindset10 = {"label": "mindset10", "pattern": [{'LEMMA': 'adaptable'}]}
mindset11 = {"label": "mindset11", "pattern": [{'LEMMA': 'pragmatism'}]}
mindset12 = {"label": "mindset12", "pattern": [{'LEMMA': 'pragmatic'}]}
mindset13 = {"label": "mindset13", "pattern": [{'LEMMA': 'opportunism'}]}
mindset14 = {"label": "mindset14", "pattern": [{'LEMMA': 'opportunistic'}]}
mindset15 = {"label": "mindset15", "pattern": [{'LEMMA': 'creative'}]}
mindset16 = {"label": "mindset16", "pattern": [{'LEMMA': 'creativity'}]}
mindset17 = {"label": "mindset17", "pattern": [{'LEMMA': 'think'}, {'LEMMA': 'differently'}]}
mindset18 = {"label": "mindset18", "pattern": [{'LEMMA': 'different'}, {'LEMMA': 'thinking'}]}
mindset19 = {"label": "mindset19", "pattern": [{'LEMMA': 'inquisitive'}]}
mindset20 = {"label": "mindset20", "pattern": [{'LEMMA': 'entrepreneurialism'}]}

#Capacity
capacity1 = {"label": "capacity1", "pattern": [{'LEMMA': 'build'},{'LEMMA': 'capacity'}]}

#Outcomes
outcome1 = {"label": "outcome1", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'impact'}]}

#From the Qual. Research 
qual1 = {"label": "qual1", "pattern": [{'POS': 'NOUN', 'OP': '?', 'ORTH': ''}, {'POS': 'VERB', 'OP': '?'}, {'LEMMA': 'alignment'}]}
qual2 = {"label": "qual2", "pattern": [{'LEMMA': 'secure'}, {'LEMMA': 'alignment'}]}
qual3 = {"label": "qual3", "pattern": [{'POS': 'VERB', 'OP': '?'}, {'POS': 'NOUN', 'OP': '?'}, {'LEMMA': 'focus'}]}
qual4 = {"label": "qual4", "pattern": [{'LEMMA': 'secure'}, {'LEMMA': 'focus'}]}
qual5 = {"label": "qual5", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'collaboratively'}]}
qual6 = {"label": "qual6", "pattern": [{'LEMMA': 'mobilisation'}]}
qual7 = {"label": "qual7", "pattern": [{'LEMMA': 'mobilise'}]}
qual8 = {"label": "qual8", "pattern": [{'POS': 'VERB', 'OP': '?'}, {'LEMMA': 'a'}, {'LEMMA': 'collective'}, {'LEMMA': 'endeavour'}]}
qual9 = {"label": "qual9", "pattern": [{'LEMMA': 'galvanise'}, {'POS': 'NOUN', 'OP': '+'}]}
qual10 = {"label": "qual10", "pattern":[{'LEMMA': 'convene'}, {'POS': 'NOUN', 'OP': '+'}]}
qual11 = {"label": "qual11", "pattern": [{'LEMMA': 'deliver'}]}
qual12 = {"label": "qual12", "pattern": [{'LEMMA': 'delivery'}]}
qual13 = {"label": "qual13", "pattern": [{'POS': 'VERB', 'OP': '+'},{'LEMMA': 'innovation', 'POS': 'NOUN'}]}
qual14 = {"label": "qual14", "pattern": [{'LEMMA': 'innovative'}]}
qual15 = {"label": "qual15", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'datum'}]}
qual16 = {"label": "qual16", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'insight'}]}
qual17 = {"label": "qual17", "pattern": [{'LEMMA': 'citizen'}, {'LEMMA': "'"}, {'LEMMA': 'experience'}]}
qual18 = {"label": "qual18", "pattern": [{'LEMMA': 'stakeholder'}, {'LEMMA': 'engagement'}]}
qual19 = {"label": "qual19", "pattern": [{'LEMMA': 'test'}, {'LEMMA': 'and'}, {'LEMMA': 'iterate'}]}
qual20 = {"label": "qual20", "pattern": [{'LEMMA': 'test'}, {'LEMMA': 'and'}, {'LEMMA': 'learn'}]}
qual21 = {"label": "qual21", "pattern": [{'POS': 'VERB', 'OP': '?'}, {'POS': 'ADJ', 'OP': '?'}, {'LEMMA': 'failure'}]}  
qual22 = {"label": "qual22", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'think'}]}
qual23 = {"label": "qual23", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'think'}]}     
qual24 = {"label": "qual24", "pattern": [{'POS': 'NOUN', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'dynamic'}]}
qual25 = {"label": "qual25", "pattern": [{'POS': 'VERB', 'OP': '+'}, {'LEMMA': 'system'}, {'LEMMA': 'dynamic'}]}    
qual26 = {"label": "qual26", "pattern": [{'LEMMA': 'prototype'}]}
qual27 = {"label": "qual27", "pattern": [{'LEMMA': 'design'}, {'LEMMA': 'thinking'}]}
qual28 = {"label": "qual28", "pattern": [{'POS': 'VERB', 'OP': '!'}, {'LEMMA': 'challenge'}, {'LEMMA': 'prize'}]}
qual29 = {"label": "qual29", "pattern": [{'LEMMA': 'humility'}]}
qual30 = {"label": "qual30", "pattern": [{'LEMMA': 'courageous'}]}
qual31 = {"label": "qual31", "pattern": [{'LEMMA': 'courage'}]}

# %%
# Combine patterns 
combined_patterns = {}

# Update the combined patterns with each set of patterns
combined_patterns = [networks1, networks2,
                    policy1, policy2, policy3, policy4, policy5, policy6,
                    intervention1, intervention2, intervention3, intervention4, intervention5, intervention6, intervention7,
                    intervention8, intervention9, intervention10, intervention11, intervention12,
                    intervention13, intervention14, intervention15,
                    buy_in1, buy_in2, buy_in3, buy_in4, buy_in5, buy_in6, buy_in7, buy_in8, buy_in9,
                    struct1,
                    sys_change1, sys_change2, sys_change3, sys_change4, sys_change5, sys_change6, sys_change7,
                    learning1, learning2, learning3, learning4, learning5, learning6, learning7, learning8, learning9, learning10, learning11, 
                    tools1, tools2, tools3, tools4, tools5, tools6, tools7, tools8, tools9, tools10, tools11, tools12, tools13, tools14,
                    tools15, tools16, tools17, tools18,tools19, tools20, tools21, tools22, tools23, tools24, tools25, tools26,
                    id1, id2, id3, id4, id5, id6, id7, id8, id9, id10, id11, id12, id13, id14,
                    delivery1, delivery2, delivery3, delivery4, delivery5, delivery6, delivery7, delivery8, delivery9,
                    mindset1, mindset2, mindset3, mindset4, mindset5, mindset6, mindset7, mindset8, mindset9, mindset10, mindset11, mindset12,
                    mindset13, mindset14, mindset15, mindset16, mindset17, mindset18, mindset19,
                    capacity1,
                    outcome1,
                    qual1, qual2, qual3, qual4, qual5, qual6, qual7, qual8, qual9, qual10, qual11, qual12, qual13, qual15, qual16, qual17, qual18, qual19, qual20, qual21, qual22, qual23, qual24, qual25, qual26, qual27, qual28, qual29, qual30, qual31
                    ]


# Serialize data to JSON
json_data = json.dumps(combined_patterns, indent=4)  

with open('patterns_skills.json', 'w') as json_file:
    json_file.write(json_data)

# %%
#For info - number of patterns created
print(len(combined_patterns))
# Out:
# 147
